# %% [markdown]
# The binder enviroment used ROOT + Python 2, but since the latter will be discontinued very soon, let's try to use Python 3 contructs...

# %%
from __future__ import absolute_import, division, generators, unicode_literals, print_function, nested_scopes, with_statement
print("Using Python 3 constructs")
# Out:
# Using Python 3 constructs

# %% [markdown]
# Let's check ROOT can be used from within a Python notebook

# %%
import ROOT

# %%
# Create simple histogram, fill it woth rando values, plot it
h = ROOT.TH1F("h","",100,-5.,5.)
h.FillRandom("gaus",10000)
c = ROOT.TCanvas("c","",800,600)
h.Draw()
c.Draw()
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: h (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
